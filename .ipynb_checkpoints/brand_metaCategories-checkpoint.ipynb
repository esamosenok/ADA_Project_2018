# %%
import pandas as pd
import numpy as np
import re
import findspark
findspark.init()
import pyspark
spark = pyspark.sql.SparkSession.builder.getOrCreate()
sc = spark.sparkContext

import warnings
warnings.filterwarnings('ignore')

# %%
#Load the data
df = spark.read\
    .format("csv")\
    .option("header", "true")\
    .option("delimiter", "\t")\
    .load('./en.openfoodfacts.org.products.csv')

#df.printSchema()

# %%
#Allow SQL queries to be executed
df.createOrReplaceTempView("df_view")

#Obtain all products that has a list of categories defined
sqlDF = spark.sql("SELECT product_name, brands_tags \
                  FROM df_view \
                  WHERE brands_tags IS NOT NULL")

#Convert it into a dataframe
brands_df = sqlDF.toPandas()

# %%
# Define the brands we are interested in

m1 = 'migros'
m2 = 'm-classic'
m3 = 'm-budget'
m4 = 'terrasuisse'
m5 = 'frey'
m6 = 'migros-bio'

c1 = 'coop'
c2 = 'coop-prix-garantie'
c3 = 'coop-naturaplan'
c4 = 'coop-naturaplan-bio'

# Order them into categories we are interested in

m_brands = [m1, m2, m3, m4, m5, m6]

c_brands = [c1, c2, c3, c4]

l_brands = [m3, c2]

b_brands = [m6, c3, c4]

# %%
#Define a function to convert them into regex

def to_regex(brands):
    """
    Convenience function that formats a list of brands into regex for the brands
    """
    pattern = "(,|^)("
    for brand in brands:
        pattern += brand + "|"
        
    pattern = pattern[:-1]
    pattern  = pattern + ")(,|$)"
    return pattern

# %%
#For each set of brands, obtain the dataframes
pattern = to_regex(c_brands)
COOP_pd = brands_df.loc[brands_df['brands_tags'].str.contains(pattern, flags=re.IGNORECASE, regex=True)]

pattern = to_regex(m_brands)
MIGROS_pd = brands_df.loc[brands_df['brands_tags'].str.contains(pattern, flags=re.IGNORECASE, regex=True)]

pattern = to_regex(l_brands)
LOCOST_pd = brands_df.loc[brands_df['brands_tags'].str.contains(pattern, flags=re.IGNORECASE, regex=True)]

pattern = to_regex(b_brands)
BIO_pd = brands_df.loc[brands_df['brands_tags'].str.contains(pattern, flags=re.IGNORECASE, regex=True)]

# %%
MIGROS_pd
# Out:
#                                              product_name  \
# 610                                   Salade de lentilles
# 10295                                                skyr
# 11524                                 Blütenhonig flüssig
# 12074                                  Mélange  randonnée
# 122518                                       jus de pomme
# 123032                                Mayonnaise M Budget
# 155907                 Premium Swiss Milk Crunchy Nut Bar
# 155908                               Dark Crunchy Nut Bar
# 155915                         Lucky Milk Chocolate Bunny
# 183800                                     Moutarde douce
# 184474                             Eau minérale naturelle
# 184534                                Panadoro provencale
# 184715       chocolat au lait fourré à la crème d'amandes
# 185154       Galettes de riz complet au chocolat au lait
# 185632                           Fromage frais aux herbes
# 195695                      Gruyère AOP salé  Switzerland
# 195697                                    Le Gruyère doux
# 195761                                  Saucisson vaudois
# 195762                             delikatess fleischkase
# 195769                                          Lard salé
# 195770                            Langue de boeuf tranche
# 195772                       Jarret de porc cuit, avec os
# 195782                     Filets de Truite Fumés du Pays
# 195783                     Filets de truite fumés du pays
# 195810                                 Coquelet / Güggeli
# 195811                                  Boudin à la crème
# 195830                                            Banane
# 195834                                      Salami Paysan
# 195835                            Charcuterie de volaille
# 195842                                    Bünder Bergkäse
# ...                                                   ...
# 422663             De la région Vinaigre Pomme Aux Herbes
# 422664                    Vinaigre de Pomme à la Raisinée
# 422677         Nature Fromage frais au lait de brebis bio
# 422678   De la région Fromage frais au lait de brebis bio
# 422679  Fromage Frais au Lait de Brebis Bio à l'Ail de...
# 422708     Biscuits avec morceaux de chocolat sans gluten
# 422744                          Multivitamin Arôme citron
# 422745                                       Multivitamin
# 422747                                         Célestines
# 422759                                         Framboises
# 422780                                  Schorle Pur Pomme
# 422781                              Be Fruits : Pur Pomme
# 422834                           Walliser Aprikosennektar
# 423020               Pain à la farine d'épeautre complète
# 429316                 Monini classico Olio extra vergine
# 429920                                 Salami Strolghino
# 430772                                Spaghetti Italpasta
# 430828                                        Chäs-Hornli
# 430829                                   Pasta Hot tomato
# 430989                       Mozzarella di Bufala Campana
# 431480                                  Carciofini interi
# 432220                       Feuilles de lasagne fraiches
# 432226                               Cannelloni bolognese
# 434962                                   Classic Branches
# 448683                                              Gouda
# 450037                                instant noodle soup
# 457146                                Spaghetti Carbonara
# 457147                                Spaghetti bolognese
# 457149                             Lasagne alla bolognese
# 457852                                   Farmer Soft Choc
#
#                                               brands_tags
# 610                                                migros
# 10295                                              migros
# 11524                                              migros
# 12074                                    sun-queen,migros
# 122518                                             migros
# 123032                                             migros
# 155907                                               frey
# 155908                                               frey
# 155915                                               frey
# 183800                                             migros
# 184474                                           m-budget
# 184534                                             migros
# 184715                                               frey
# 185154                                         migros-bio
# 185632                                    m-budget,migros
# 195695                                             migros
# 195697                                             migros
# 195761                            migros,suter-viandes-sa
# 195762                                             migros
# 195769                                             migros
# 195770                                             migros
# 195772                                             migros
# 195782                                de-la-region,migros
# 195783                                             migros
# 195810                                     migros,micarna
# 195811                                             migros
# 195830                                             migros
# 195834                                             migros
# 195835                                             migros
# 195842                                       leger,migros
# ...                                                   ...
# 422663                                             migros
# 422664                                de-la-region,migros
# 422677                                         migros-bio
# 422678                                         migros-bio
# 422679                                migros,de-la-region
# 422708                                         migros,aha
# 422744                                    m-budget,migros
# 422745                                         migros-bio
# 422747                                          m-classic
# 422759                                    m-budget,migros
# 422780                                   be-fruits,migros
# 422781                                migros,de-la-region
# 422834                                             migros
# 423020                                             migros
# 429316                                      monini,migros
# 429920                                             migros
# 430772                                             migros
# 430828                                      subito,migros
# 430829                                      subito,migros
# 430989                                             migros
# 431480                                       polli,migros
# 432220  armando-de-angelis-pastaio,migros,armando-de-a...
# 432226                  armando-de-angelis-pastaio,migros
# 434962                                               frey
# 448683                                             migros
# 450037                                      nissin,migros
# 457146                                   m-classic,migros
# 457147                                   m-classic,migros
# 457149                                    m-budget,migros
# 457852                                             migros
#
# [2408 rows x 2 columns]
